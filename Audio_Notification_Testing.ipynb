# %% [markdown]
# <a href="https://colab.research.google.com/github/ishanyaa/Python_Collab/blob/master/Audio_Notification_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Audio, display

# Upload the sound file
uploaded = files.upload()

# Play the sound
def output_sound():
    display(Audio("alert1.wav", autoplay=True))

# Play sound after code execution
output_sound()
# Out:
#      <input type="file" id="files-c64010aa-3310-4857-a5b7-a6b6b9aa685c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c64010aa-3310-4857-a5b7-a6b6b9aa685c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def bubble_sort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n):
        # Last i elements are already sorted
        for j in range(0, n-i-1):
            # Traverse the array from 0 to n-i-1
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# Example usage:
arr = [64, 34, 25, 12, 22, 11, 90]
bubble_sort(arr)
print("Sorted array is:", arr)



output_sound()
# Out:
# Sorted array is: [11, 12, 22, 25, 34, 64, 90]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Hello World")

output_sound()
# Out:
# Hello World
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def bubble_sort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n):
        # Last i elements are already sorted
        for j in range(0, n-i-1):
            # Traverse the array from 0 to n-i-1
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]


# Example usage:
arr = [64, 34, 25, 12, 22, 11, 90, 72387, 434893,773, 99390, 427382738, 4364443, 3902, 329302323, 327328323, 32443, 347387434, 437387248327438434343, 3373, 20929, 37737, 92388383, 38388377477488373828, 373823823723, 1, 238372, 898, 389383, 3928328]
bubble_sort(arr)
print("Sorted array is:", arr)



output_sound()
# Out:
# Sorted array is: [1, 11, 12, 22, 25, 34, 64, 90, 773, 898, 3373, 3902, 20929, 32443, 37737, 72387, 99390, 238372, 389383, 434893, 3928328, 4364443, 92388383, 327328323, 329302323, 347387434, 427382738, 373823823723, 38388377477488373828, 437387248327438434343]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # ONLINE NOTEBOOK

# %%
from IPython.display import Audio, display
import requests

# URL of the sound file
sound_url = "https://prodigits.co.uk/content/ringtones/tone/2020/alert/newshortsm_3f130d9c5321615.mp3"

def play_sound():
    display(Audio(sound_url, autoplay=True))

# Your code here
# ...

# Play sound after code execution
play_sound()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def bubble_sort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n):
        # Last i elements are already sorted
        for j in range(0, n-i-1):
            # Traverse the array from 0 to n-i-1
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]


# Example usage:
arr = [64, 34, 25, 12, 22, 11, 90, 72387, 434893,773, 99390, 427382738, 4364443, 3902, 329302323, 327328323, 32443, 347387434, 437387248327438434343, 3373, 20929, 37737, 92388383, 38388377477488373828, 373823823723, 1, 238372, 898, 389383, 3928328]
bubble_sort(arr)
print("Sorted array is:", arr)



play_sound()
# Out:
# Sorted array is: [1, 11, 12, 22, 25, 34, 64, 90, 773, 898, 3373, 3902, 20929, 32443, 37737, 72387, 99390, 238372, 389383, 434893, 3928328, 4364443, 92388383, 327328323, 329302323, 347387434, 427382738, 373823823723, 38388377477488373828, 437387248327438434343]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def counting_sort(arr, exp):
    n = len(arr)
    output = [0] * n  # The output array that will have sorted numbers
    count = [0] * 10  # Initialize count array as 0

    # Store count of occurrences in count[]
    for i in range(n):
        index = arr[i] // exp
        count[index % 10] += 1

    # Change count[i] so that it contains the actual position of this digit in output[]
    for i in range(1, 10):
        count[i] += count[i - 1]

    # Build the output array
    i = n - 1
    while i >= 0:
        index = arr[i] // exp
        output[count[index % 10] - 1] = arr[i]
        count[index % 10] -= 1
        i -= 1

    # Copy the output array to arr[], so that arr now contains sorted numbers according to the current digit
    for i in range(n):
        arr[i] = output[i]

def radix_sort(arr):
    # Find the maximum number to know the number of digits
    max1 = max(arr)

    # Do counting sort for every digit. Note that exp is 10^i where i is the current digit number
    exp = 1
    while max1 // exp > 0:
        counting_sort(arr, exp)
        exp *= 10

# Example usage
arr = [170, 45, 75, 90, 802, 24, 2, 66]
radix_sort(arr)
print("Sorted array is:", arr)


play_sound()
# Out:
# Sorted array is: [2, 24, 45, 66, 75, 90, 170, 802]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
